# %% [markdown]
# <a href="https://colab.research.google.com/github/mendeseduarda/rede-neural/blob/main/RNA01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')
plt.rcParams['figure.figsize']=(10,8)

# %% [markdown]
# # Criar dataSet

# %%
def get_linear_curve(x, w, b=0):
  return w*x+b

# %%
x = np.arange(-10, 30.1, 0.5)
y = get_linear_curve(x, 1.8, 32)

# %%
plt.scatter(x,y)
plt.xlabel('ºC', fontsize=20)
plt.ylabel('ºF', fontsize=20)
# Out:
# Text(0, 0.5, 'ºF')
